# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X =  2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# %%
plt.scatter(X, y)
plt.ylim(0, 14)
plt.title('Randomly generated linear dataset')
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

theta_best
# Out:
# array([[4.41379038],
#        [3.06643426]])

# %%
# Make predictions
X_new     = np.array([[0], [2]])
X_new_b   = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 4.41379038],
#        [10.54665891]])

# %%
plt.scatter(X, y)
plt.ylim(0, 14)
plt.title('Randomly generated linear dataset')

plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")

plt.axis([-0.5, 2.5, -1, 15])
plt.grid(True,)

plt.show()

# %% [markdown]
# Performing linear regression using Scikit-Learn is quite simple

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([4.41379038]), array([[3.06643426]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[ 4.41379038],
#        [10.54665891]])

# %% [markdown]
# The LinearRegression class is based on the scipy.linalg.lstsq() function (the
# name stands for “least squares”), which you could call directly

# %%
theta_best_svd, residuals, rank, s = np.linalg.lstsq(a=X_b, b=y, rcond=1e-6)
theta_best_svd
# Out:
# array([[4.41379038],
#        [3.06643426]])

# %%
np.linalg.pinv(X_b).dot(y)
# Out:
# array([[4.41379038],
#        [3.06643426]])

# %% [markdown]
# Gradient descent step

# %%
eta = 0.1 
n_iterations = 1000
m = 100

theta = np.random.randn(2, 1)
theta
# Out:
# array([[-1.44407945],
#        [-0.85798342]])

# %%
for iteration in range(n_iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - eta * gradients

# %%
theta
# Out:
# array([[4.41379038],
#        [3.06643426]])
